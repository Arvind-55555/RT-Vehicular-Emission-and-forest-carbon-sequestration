# %% [markdown]
# # Example Notebook
#
# This is an example notebook to verify the Jupyter Notebook Validation workflow.

# %%
import pandas as pd
import numpy as np

print("Hello, World!")

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df.head())
